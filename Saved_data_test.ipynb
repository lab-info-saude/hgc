# %%
import matplotlib.pyplot as plt
from Data_Savior import load_file
w1 = load_file("./preprocessed_data/JULIANA2701w3.data")

# %%
print w1.keys()
print w1['right'].keys()
print w1['left'].keys()
# %matplotlib inline
#colocar o frame rate tambem nos dados salvos
# Out:
# ['right', 'left']
# ['3d velocities', 'angular accelerations', 'angular velocities', 'angles']
# ['3d velocities', 'angular accelerations', 'angular velocities', 'angles']

# %%
#plotting the ones on the right
print "                 Right Knee"
plt.plot(w1['right']['3d velocities'][:, 0])
plt.title("X velocities")
plt.show()

plt.plot(w1['right']['3d velocities'][:, 1])
plt.title("Y velocities")
plt.show()

plt.plot(w1['right']['3d velocities'][:, 2])
plt.title("Z velocities")
plt.show()

plt.plot(w1['right']['angular accelerations'])
plt.title("Angular Accelerations")
plt.show()

plt.plot(w1['right']['angular velocities'])
plt.title("Angular Velocities")
plt.show()

plt.plot(w1['right']['angles'])
plt.title("Angles")
plt.show()
# Out:
#                  Right Knee

# %%
#plotting the ones on the left
print "                 Left Knee"
plt.plot(w1['left']['3d velocities'][:, 0])
plt.title("X velocities")
plt.show()

plt.plot(w1['left']['3d velocities'][:, 1])
plt.title("Y velocities")
plt.show()

plt.plot(w1['left']['3d velocities'][:, 2])
plt.title("Z velocities")
plt.show()

plt.plot(w1['left']['angular accelerations'])
plt.title("Angular Accelerations")
plt.show()

plt.plot(w1['left']['angular velocities'])
plt.title("Angular Velocities")
plt.show()

plt.plot(w1['left']['angles'])
plt.title("Angles")
plt.show()
# Out:
#                  Left Knee
